# %%
import os
import random
import time
import h5py
import numpy as np
import pandas as pd
import scipy.io
import librosa
import kagglehub
import h5py
import shutil
import IPython.display as ipd
import matplotlib.pyplot as plt

from IPython.display import display, Audio
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score 
#from sktime.classification.kernel_based import RocketClassifier
from sktime.transformations.panel.rocket import Rocket
from sklearn.model_selection import GroupKFold
from sklearn.metrics import classification_report
from detach_rocket.detach_classes import DetachRocket
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sktime.classification.kernel_based import RocketClassifier

# %%
import librosa
audio, sr = librosa.load("datasets/prueba_mic/prueba_audio2.wav", sr=None)
print("Máximo volumen captado:", audio.max())
# Out:
# Máximo volumen captado: 0.0

# %%
# ==================================================
# 2. CARGA Y CONCATENACIÓN DE BABBLE NOISE (LOCAL)
# ==================================================
babble_exact_path = "datasets/noise/0dB/valid/real" 

audio_buffers_list = []
max_archivos_a_combinar = 40 
sr_original = 16000
sr_objetivo = 22050

archivos_mat = 0

for f in os.listdir(babble_exact_path):
    if len(audio_buffers_list) >= max_archivos_a_combinar:
        break

    file_path = os.path.join(babble_exact_path, f)
    
    if file_path.endswith('.mat'):
            mat_contents = scipy.io.loadmat(file_path) #esta funcion convierte el .mat en un diccionario 
            keys = [k for k in mat_contents.keys() if not k.startswith('__')] # cuando SciPy lee un .mat, automáticamente le inyecta variables internas de configuración que siempre empiezan con doble guion bajo (ej: __header. 
            #armo una lista solo con los nombres de las variables "reales" que contienen el audio
            if keys:
                audio_raw = mat_contents[keys[0]].flatten().astype(np.float32) 
                #mat_contents[keys[0]] extrae los datos almacenados en la primera clave válida
                # .flatten(): "aplasta" esa matriz para convertirla en un vector 1D
                # .astype(np.float32): conversión a formato decimal de 32 bits (float32).
                if audio_raw.size > 0:
                    audio_buffers_list.append(audio_raw)
                    archivos_mat += 1

# Procesamiento final
print("-" * 50)
print(f" - Archivos .mat procesados: {archivos_mat}")
# Out:
# --------------------------------------------------
#  - Archivos .mat procesados: 40

# %%
babble_completo_16k = np.concatenate(audio_buffers_list)
babble_audio_full = librosa.resample(babble_completo_16k, orig_sr=sr_original, target_sr=sr_objetivo) #la paso a la sample rate que necesito

# %%
# ==================================================
# 3. FUNCIONES DE DATA AUGMENTATION
# ==================================================

#RUIDO BLANCO
def add_white_noise(audio, noise_level=0.005):
    noise = np.random.randn(len(audio)) #vector de numeros aleatorios con la misma longitud que mi vector original
    return audio + noise_level * noise

# %%
#RUIDO ROSA
def add_pink_noise(audio, noise_level=0.01):
    #el ruido rosa se caracteriza por tener una densidad espectral inversa a la frecuencia (es decir, 1/f)
    white = np.random.randn(len(audio)) #genero ruido blanco
    fft_white = np.fft.rfft(white) #transformada de fourier - paso el ruido blanco a dominio de la frecuencia. Ya no es la potencia, es la amplitud la que veo representada
    frequencies = np.maximum(np.fft.rfftfreq(len(audio)), 1e-10) #crea un vector de frecuencias. SI hay un valor menor a 1e-10, lo reemplaza por este número.
    #Elijo 1e-10 porque es un numero cercano a cero, sin ser cero.
    f_filter = 1.0 / np.sqrt(frequencies) #En la línea anterior, me aseguré de que no queden divisiones por cero. V^2 = P -> 1/sqrt(f) = P (ver notas)
    f_filter /= np.max(f_filter) #Busca el numero mas grande que haya quedado dentro del array y divide a todos los valores por este numero
    fft_pink = fft_white * f_filter #Aplica el filtro al ruido blanco en el dominio de la frecuencia.
    pink = np.fft.irfft(fft_pink, n=len(audio)) #Conversion al dominio del tiempo
    pink = pink / np.max(np.abs(pink)) #normalizacion
    return audio + noise_level * pink

# %%
#MULTITALKER BABBLE NOISE 
def add_babble_noise(audio, babble_audio, noise_level=0.03):
    # np.tile -> construye un nuevo array repitiendo el primer argumento (en este caso, babble_audio) la cantidad de veces que se pida. 
    # Esto se aplica solo si el audio es menor al audio original  
    #np.ceil -> devuelve el menor escalar i tal que i>=x
    if len(babble_audio) < len(audio):
        babble_audio = np.tile(babble_audio, int(np.ceil(len(audio) / len(babble_audio))))

    # toma un punto de inicio random
    start_idx = random.randint(0, len(babble_audio) - len(audio))
    babble_chunk = babble_audio[start_idx : start_idx + len(audio)] #aplico babble noise desde mi punto random hasta el final del audio
    babble_chunk = babble_chunk / (np.max(np.abs(babble_chunk)) + 1e-10) #normalizo el murmullo para que no haya picos de volumen descontrolados

    return audio + noise_level * babble_chunk

# %%
# ==========================================
# 4. DESCARGA Y CURACIÓN DEL DATASET LOCAL
# ==========================================
dataset_root_path = kagglehub.dataset_download("mmoreaux/environmental-sound-classification-50")

metadata_path = None
for root, dirs, files in os.walk(dataset_root_path):
    if 'esc50.csv' in files:
        metadata_path = os.path.join(root, 'esc50.csv')
        break

if metadata_path:
    df = pd.read_csv(metadata_path)
    print("Archivo de metadatos cargado correctamente.")

mis_clases = ['clock_alarm', 'door_wood_knock', 'cat', 'crying_baby', 'dog', 'glass_breaking']
df_filtrado = df[df['category'].isin(mis_clases)].copy()

kaggle_audio_dir = None
for root, dirs, files in os.walk(dataset_root_path): #Busca donde estan los archivos
    if any(f.endswith('.wav') for f in files):
        kaggle_audio_dir = root
        break

target_dir = "datasets/audios_originales"
archivos_copiados = 0

for index, row in df_filtrado.iterrows():
    src_path = os.path.join(kaggle_audio_dir, row['filename'])
    dst_path = os.path.join(target_dir, row['filename'])
    
    # Solo lo copio si el archivo original existe y no esta en el directorio audios_originales
    if os.path.exists(src_path) and not os.path.exists(dst_path):
        shutil.copy2(src_path, dst_path)
        archivos_copiados += 1

print(f"Se copiaron {archivos_copiados} archivos nuevos.")
# Out:
# Archivo de metadatos cargado correctamente.
# Se copiaron 0 archivos nuevos.

# %%
# ==========================================
# 5. TRANSFORMACIÓN A MFCC Y DATA AUGMENTATION. 
# Paso a espectograma
# ==========================================
correct_audio_dir = target_dir 

X_list = []
y_list = []
groups = []

n_mfcc = 40 #Se puede jugar con este valor. representa la cantidad de caracteristicas acusticas (coef) que librosa 
#extrajo en un instante de t para imitar como percibe el oido humano el audio.

hop_length = 512

for index, row in df_filtrado.iterrows(): 
    file_path = os.path.join(correct_audio_dir, row['filename']) 
    categoria = row['category'] 
    
    y_audio, sr = librosa.load(file_path, sr=22050) 

    audios_a_procesar = [
            y_audio,                                     
            add_white_noise(y_audio),                    
            add_pink_noise(y_audio),                     
            add_babble_noise(y_audio, babble_audio_full) 
        ]

    # Convertir a MFCC
    for audio_version in audios_a_procesar:
        mfccs = librosa.feature.mfcc(y=audio_version, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length)
        
        X_list.append(mfccs)
        y_list.append(categoria)
        groups.append(row['filename'])

X = np.array(X_list)
y = np.array(y_list)
groups = np.array(groups)

print("-" * 50)
print(f"Forma final de la matriz X: {X.shape}") #(960, 40, 216) (cantidad de muestras, variables, ventanas de tiempo)
print(f"Cantidad de etiquetas y: {y.shape}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 31
#      29 # Convertir a MFCC
#      30 for audio_version in audios_a_procesar:
# ---> 31     mfccs = librosa.feature.mfcc(y=audio_version, sr=sr, n_mfcc=n_mfcc, hop_length=hop_length)
#      33     X_list.append(mfccs)
#      34     y_list.append(categoria)
#
# File /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/librosa/feature/spectral.py:1993, in mfcc(y, sr, S, n_mfcc, dct_type, norm, lifter, mel_norm, **kwargs)
#    1846 """Mel-frequency cepstral coefficients (MFCCs)
#    1847
#    1848 .. warning:: If multi-channel audio input ``y`` is provided, the MFCC
#    (...)
#    1989 >>> fig.colorbar(img2, ax=[ax[1]])
#    1990 """
#    1991 if S is None:
#    1992     # multichannel behavior may be different due to relative noise floor differences between channels
# -> 1993     S = power_to_db(melspectrogram(y=y, sr=sr, norm = mel_norm, **kwargs))
#    1995 fft = get_fftlib()
#    1996 M: np.ndarray = fft.dct(S, axis=-2, type=dct_type, norm=norm)[
#    1997     ..., :n_mfcc, :
#    1998 ]
#
# File /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/librosa/feature/spectral.py:2150, in melspectrogram(y, sr, S, n_fft, hop_length, win_length, window, center, pad_mode, power, **kwargs)
#    2147 # Build a Mel filter
#    2148 mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# -> 2150 melspec: np.ndarray = np.einsum("...ft,mf->...mt", S, mel_basis, optimize=True)
#    2151 return melspec
#
# File /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/numpy/core/einsumfunc.py:1419, in einsum(out, optimize, *operands, **kwargs)
#    1416     right_pos.append(input_right.find(s))
#    1418 # Contract!
# -> 1419 new_view = tensordot(*tmp_operands, axes=(tuple(left_pos), tuple(right_pos)))
#    1421 # Build a new view if needed
#    1422 if (tensor_result != results_index) or handle_out:
#
# File /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/numpy/core/numeric.py:1121, in tensordot(a, b, axes)
#    1119 at = a.transpose(newaxes_a).reshape(newshape_a)
#    1120 bt = b.transpose(newaxes_b).reshape(newshape_b)
# -> 1121 res = dot(at, bt)
#    1122 return res.reshape(olda + oldb)
#
# KeyboardInterrupt:

# %%
# ==========================================
# 6. ENTRENAMIENTO ROCKET / DETACH ROCKET CON MFCC
# ==========================================

le = LabelEncoder()
y_encoded = le.fit_transform(y)

gkf = GroupKFold(n_splits=5) 

accuracies = []
all_y_true = []
all_y_pred = []

print("-" * 50)
print(f"Total de muestras aumentadas: {len(X)}")
print(f"Forma de entrada al modelo: {X.shape} (muestras, coeficientes, tiempo)")

for fold, (train_index, test_index) in enumerate(gkf.split(X, y_encoded, groups=groups)): 
    print(f"\n INICIANDO FOLD {fold+1} DE 5")
    
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y_encoded[train_index], y_encoded[test_index]
    
    kernels_a_usar = 5000
    print(f"   [{time.strftime('%H:%M:%S')}] Entrenando Rocket con {kernels_a_usar} kernels...")
    
    start_time = time.time()
    
    #modelo = RocketClassifier(num_kernels=kernels_a_usar, random_state=42)
    modelo = DetachRocket('rocket', num_kernels=5000)

    modelo.fit(X_train, y_train)
    
    tiempo_entrenamiento = (time.time() - start_time) / 60
    print(f"   Entrenamiento listo. Tardó: {tiempo_entrenamiento:.2f} minutos.")
    
    # Predicción y Evaluación
    y_pred = modelo.predict(X_test)
    all_y_true.extend(y_test)
    all_y_pred.extend(y_pred)
    
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)
    
    print(f" - Fold {fold+1}: Accuracy = {acc:.4f}")

# Resultado final
print("\n" + "=" * 50)
print(f"ACCURACY PROMEDIO FINAL: {np.mean(accuracies):.4f}")
print("=" * 50)
# Out:
# --------------------------------------------------
# Total de muestras aumentadas: 960
# Forma de entrada al modelo: (960, 40, 216) (muestras, coeficientes, tiempo)
#
#  INICIANDO FOLD 1 DE 5
#    [19:16:34] Entrenando Rocket con 5000 kernels...
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 0.00
# Train Accuraccy Full ROCKET: 100.00%
# -------------------------
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.44789e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.65347e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.80032e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.28887e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.31405e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.72307e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.34811e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.88469e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.04043e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.20217e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=9.54711e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.4438e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=8.63053e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.93826e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.64405e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=9.8412e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.51667e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.21934e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.79573e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.48887e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.2177e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=3.63897e-09): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 100.00%
# -------------------------
#    Entrenamiento listo. Tardó: 0.25 minutos.
#  - Fold 1: Accuracy = 0.8646
#
#  INICIANDO FOLD 2 DE 5
#    [19:16:52] Entrenando Rocket con 5000 kernels...
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 0.00
# Train Accuraccy Full ROCKET: 100.00%
# -------------------------
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.58641e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.25262e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.18106e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.89042e-12): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=7.3597e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.57211e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.57723e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.2524e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.41204e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.88045e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.21065e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.7176e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.70037e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.83338e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.25963e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.88616e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.28977e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.22242e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.07197e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.5497e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.47334e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.75421e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.25788e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.21998e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.61751e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.22888e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.01556e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.30475e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.65593e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.84772e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.80847e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.81662e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=8.81286e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.05033e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.51662e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.67878e-12): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.44569e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=9.55788e-10): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 100.00%
# -------------------------
#    Entrenamiento listo. Tardó: 0.24 minutos.
#  - Fold 2: Accuracy = 0.8698
#
#  INICIANDO FOLD 3 DE 5
#    [19:17:10] Entrenando Rocket con 5000 kernels...
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 0.00
# Train Accuraccy Full ROCKET: 100.00%
# -------------------------
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.35094e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.15754e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.35822e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.68861e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.80643e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.74645e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=8.82641e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.69721e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.72728e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.71578e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.36686e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.07214e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.71909e-12): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.16148e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.15635e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.66684e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.64223e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.27035e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.09557e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.73187e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.08598e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.19282e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.6024e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.32215e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.04863e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.47862e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.11471e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.39686e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.32221e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.9427e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.95449e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=9.53999e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=7.14512e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.69349e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.39837e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.87678e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.94645e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.18923e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.39545e-10): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.11658e-09): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 100.00%
# -------------------------
#    Entrenamiento listo. Tardó: 0.24 minutos.
#  - Fold 3: Accuracy = 0.8594
#
#  INICIANDO FOLD 4 DE 5
#    [19:17:27] Entrenando Rocket con 5000 kernels...
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 0.00
# Train Accuraccy Full ROCKET: 100.00%
# -------------------------
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.62465e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.44677e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.10134e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.38146e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.5981e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=8.01948e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.0115e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.26249e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=8.63276e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.39393e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=7.14828e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.36737e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.03221e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.64738e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# ...
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.62651e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=1.16763e-09): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 100.00%
# -------------------------
#    Entrenamiento listo. Tardó: 0.24 minutos.
#  - Fold 4: Accuracy = 0.8802
#
#  INICIANDO FOLD 5 DE 5
#    [19:17:45] Entrenando Rocket con 5000 kernels...
# TRAINING RESULTS Full ROCKET:
# Optimal Alpha Full ROCKET: 0.00
# Train Accuraccy Full ROCKET: 100.00%
# -------------------------
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.78082e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.81436e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.14963e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.28566e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.54512e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.15463e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.5093e-12): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.31952e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.79661e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.88103e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.93224e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.90702e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.33063e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=8.24751e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.11445e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.87376e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.2302e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.30349e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.68288e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.45694e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=9.13785e-11): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:252: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.66931e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.26933e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.27078e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.75972e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=8.49858e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.53273e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.82002e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.38881e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.82383e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.77809e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.80611e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=7.19593e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=4.86074e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.82558e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.27201e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=3.31087e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.50127e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.64726e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.96153e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.11053e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=6.81855e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=1.06806e-09): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=5.09781e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=2.84277e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:250: LinAlgWarning: Ill-conditioned matrix (rcond=7.6849e-10): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=6.21158e-10): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/miniconda3/envs/pfi_audio/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:213: LinAlgWarning: Ill-conditioned matrix (rcond=4.75689e-08): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# TRAINING RESULTS Detach Model:
# Optimal Alpha Detach Model: 37.93
# Train Accuraccy Detach Model: 100.00%
# -------------------------
#    Entrenamiento listo. Tardó: 0.24 minutos.
#  - Fold 5: Accuracy = 0.7917
#
# ==================================================
# ACCURACY PROMEDIO FINAL: 0.8531
# ==================================================

# %%
# ==========================================
# 7. MATRIZ DE CONFUSION
# ==========================================

cm = confusion_matrix(all_y_true, all_y_pred)

# Recuperamos los nombres originales de las etiquetas (ej: 'dog', 'siren', etc.)
nombres_clases = le.classes_ 

# Graficamos
fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=nombres_clases)
disp.plot(ax=ax, cmap='Blues', xticks_rotation=45)

plt.title('Matriz de confusión - DetachRocket', fontsize=14)
plt.xlabel('Predicción del Modelo', fontsize=12)
plt.ylabel('Sonido Real', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# ==========================================
# 8. EXPORTAR MODELO
# ==========================================

import joblib

joblib.dump(modelo, 'modelo_exportado.pkl')
joblib.dump(le, 'label_encoder.pkl')
# Out:
# ['label_encoder.pkl']
